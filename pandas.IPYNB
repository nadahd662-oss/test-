# %% [markdown]
# # IMPORTING

# %%
import pandas as pd

# %% [markdown]
# ## code

# %% [markdown]
# ### READ AND PRINTING

# %%
df = pd.read_csv("downloaded_file.csv")

print(df.head())
# Out:
#    id                product_name                        url       category  \
# 0   1  CVS Health Ibuprofen 200mg  https://www.cvs.com/p/001    Pain Relief
# 1   2        CVS Vitamin C 1000mg  https://www.cvs.com/p/002       Vitamins
# 2   3    CVS Hydrating Face Wipes  https://www.cvs.com/p/003  Personal Care
# 3   4     CVS Allergy Relief 24HR  https://www.cvs.com/p/004        Allergy
# 4   5         CVS Daily Probiotic  https://www.cvs.com/p/005    Supplements
#
#    price  availability  rating  reviews_count            sku retrieved_at
# 0   5.49      In Stock     4.7            234    CVS-IBU-200   2025-12-10
# 1  12.99      In Stock     4.8            189  CVS-VITC-1000   2025-12-10
# 2   6.29  Out of Stock     4.4             57   CVS-FACEW-01   2025-12-10
# 3  21.49      In Stock     4.6            301    CVS-ALGY-24   2025-12-10
# 4  18.99      In Stock     4.5            142  CVS-PROBIO-01   2025-12-10
